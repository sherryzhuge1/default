# %%
import pandas as pd
import numpy as np

# %%
field_names = [
    "Reference Pool ID", "Loan Identifier", "Monthly Reporting Period", "Channel",
    "Seller Name", "Servicer Name", "Master Servicer", "Original Interest Rate",
    "Current Interest Rate", "Original UPB", "UPB at Issuance", "Current Actual UPB",
    "Original Loan Term", "Origination Date", "First Payment Date", "Loan Age",
    "Remaining Months to Legal Maturity", "Remaining Months To Maturity", "Maturity Date",
    "Original Loan to Value Ratio (LTV)", "Original Combined Loan to Value Ratio (CLTV)",
    "Number of Borrowers", "Debt-To-Income (DTI)", "Borrower Credit Score at Origination",
    "Co-Borrower Credit Score at Origination", "First Time Home Buyer Indicator", "Loan Purpose",
    "Property Type", "Number of Units", "Occupancy Status", "Property State", "Metropolitan Statistical Area (MSA)",
    "Zip Code Short", "Mortgage Insurance Percentage", "Amortization Type", "Prepayment Penalty Indicator",
    "Interest Only Loan Indicator", "Interest Only First Principal And Interest Payment Date",
    "Months to Amortization", "Current Loan Delinquency Status", "Loan Payment History", "Modification Flag",
    "Mortgage Insurance Cancellation Indicator", "Zero Balance Code", "Zero Balance Effective Date",
    "UPB at the Time of Removal", "Repurchase Date", "Scheduled Principal Current", "Total Principal Current",
    "Unscheduled Principal Current", "Last Paid Installment Date", "Foreclosure Date", "Disposition Date",
    "Foreclosure Costs", "Property Preservation and Repair Costs", "Asset Recovery Costs", "Miscellaneous Holding Expenses and Credits",
    "Associated Taxes for Holding Property", "Net Sales Proceeds", "Credit Enhancement Proceeds", "Repurchase Make Whole Proceeds",
    "Other Foreclosure Proceeds", "Modification-Related Non-Interest Bearing UPB", "Principal Forgiveness Amount",
    "Original List Start Date", "Original List Price", "Current List Start Date", "Current List Price", "Borrower Credit Score At Issuance",
    "Co-Borrower Credit Score At Issuance", "Borrower Credit Score Current", "Co-Borrower Credit Score Current",
    "Mortgage Insurance Type", "Servicing Activity Indicator", "Current Period Modification Loss Amount",
    "Cumulative Modification Loss Amount", "Current Period Credit Event Net Gain or Loss", "Cumulative Credit Event Net Gain or Loss",
    "Special Eligibility Program", "Foreclosure Principal Write-off Amount", "Relocation Mortgage Indicator",
    "Zero Balance Code Change Date", "Loan Holdback Indicator", "Loan Holdback Effective Date", "Delinquent Accrued Interest",
    "Property Valuation Method", "High Balance Loan Indicator", "ARM Initial Fixed-Rate Period ≤ 5 YR Indicator", "ARM Product Type",
    "Initial Fixed-Rate Period", "Interest Rate Adjustment Frequency", "Next Interest Rate Adjustment Date", "Next Payment Change Date",
    "Index", "ARM Cap Structure", "Initial Interest Rate Cap Up Percent", "Periodic Interest Rate Cap Up Percent",
    "Lifetime Interest Rate Cap Up Percent", "Mortgage Margin", "ARM Balloon Indicator", "ARM Plan Number",
    "Borrower Assistance Plan", "High Loan to Value (HLTV) Refinance Option Indicator", "Deal Name", "Repurchase Make Whole Proceeds Flag",
    "Alternative Delinquency Resolution", "Alternative Delinquency  Resolution Count", "Total Deferral Amount",
    "Payment Deferral Modification Event Indicator", "Interest Bearing UPB"
]
columns_to_keep = [
    "Loan Identifier",
    "Monthly Reporting Period",
    "Channel",
    "Original Interest Rate",
    "Current Interest Rate",
    "Original UPB",
    "Current Actual UPB",
    "Original Loan Term",
    "Origination Date",
    "Loan Age",
    "Original Loan to Value Ratio (LTV)",
    "Original Combined Loan to Value Ratio (CLTV)",
    "Number of Borrowers",
    "Debt-To-Income (DTI)",
    "Borrower Credit Score at Origination",
    "Co-Borrower Credit Score at Origination",
    "First Time Home Buyer Indicator",
    "Loan Purpose",
    "Property Type",
    "Number of Units",
    "Occupancy Status",
    "Property State",
    "Metropolitan Statistical Area (MSA)",
    "Zip Code Short",
    "Mortgage Insurance Percentage",
    "Amortization Type",
    "Prepayment Penalty Indicator",
    "Interest Only Loan Indicator",
    "Current Loan Delinquency Status",
    "Loan Payment History",
    "Modification Flag",
    "Mortgage Insurance Cancellation Indicator",
    "Zero Balance Code",
    "Zero Balance Effective Date",
    "UPB at the Time of Removal",
    "Borrower Credit Score Current",
    "Co-Borrower Credit Score Current",
    "Mortgage Insurance Type",
    "Property Valuation Method",
    "ARM Product Type"
]

# %%
q1 = r'C:\Users\ying_\SHERRY\mortgage\2012\2012Q1.csv'
output_file = "subset_2012_Q1.csv"

chunk1 = pd.read_csv(q1, delimiter='|', header=None, na_values=[',,', '', ','], skipinitialspace=True, chunksize=1000000)
first_chunk = True
for chunk in chunk1:
    chunk.columns = field_names
    chunk = chunk[columns_to_keep]
    if first_chunk:
        chunk.to_csv(output_file, index=False)
        first_chunk = False
    else:
        chunk.to_csv(output_file, mode='a', header=False, index=False)
# Out:
# C:\Users\ying_\AppData\Local\Temp\ipykernel_13972\1060763550.py:6: DtypeWarning: Columns (40,101,105) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk1:
# C:\Users\ying_\AppData\Local\Temp\ipykernel_13972\1060763550.py:6: DtypeWarning: Columns (40,101,105) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk1:
# C:\Users\ying_\AppData\Local\Temp\ipykernel_13972\1060763550.py:6: DtypeWarning: Columns (40,101,105) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk1:
# C:\Users\ying_\AppData\Local\Temp\ipykernel_13972\1060763550.py:6: DtypeWarning: Columns (40,101,105) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk1:
# C:\Users\ying_\AppData\Local\Temp\ipykernel_13972\1060763550.py:6: DtypeWarning: Columns (40,101,105) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
q2 = r'C:\Users\ying_\SHERRY\mortgage\2012\2012Q2.csv'
output_file = "subset_2012_Q2.csv"

chunk2 = pd.read_csv(q2, delimiter='|', header=None, na_values=[',,', '', ','], skipinitialspace=True, chunksize=1000000)
first_chunk = True
for chunk in chunk2:
    chunk.columns = field_names
    chunk = chunk[columns_to_keep]
    if first_chunk:
        chunk.to_csv(output_file, index=False)
        first_chunk = False
    else:
        chunk.to_csv(output_file, mode='a', header=False, index=False)
# Out:
# C:\Users\ying_\AppData\Local\Temp\ipykernel_13972\847829901.py:6: DtypeWarning: Columns (40,101,105) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk2:
# C:\Users\ying_\AppData\Local\Temp\ipykernel_13972\847829901.py:6: DtypeWarning: Columns (40,101,105) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk2:
# C:\Users\ying_\AppData\Local\Temp\ipykernel_13972\847829901.py:6: DtypeWarning: Columns (40,101,105) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk2:
# C:\Users\ying_\AppData\Local\Temp\ipykernel_13972\847829901.py:6: DtypeWarning: Columns (40,101,105) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk2:
# C:\Users\ying_\AppData\Local\Temp\ipykernel_13972\847829901.py:6: DtypeWarning: Columns (40,101,105) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
q3 = r'C:\Users\ying_\SHERRY\mortgage\2012\2012Q3.csv'
output_file = "subset_2012_Q3.csv"

chunk2 = pd.read_csv(q3, delimiter='|', header=None, na_values=[',,', '', ','], skipinitialspace=True, chunksize=1000000)
first_chunk = True
for chunk in chunk2:
    chunk.columns = field_names
    chunk = chunk[columns_to_keep]
    if first_chunk:
        chunk.to_csv(output_file, index=False)
        first_chunk = False
    else:
        chunk.to_csv(output_file, mode='a', header=False, index=False)
# Out:
# C:\Users\ying_\AppData\Local\Temp\ipykernel_13972\1563985282.py:6: DtypeWarning: Columns (40,105) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk2:
# C:\Users\ying_\AppData\Local\Temp\ipykernel_13972\1563985282.py:6: DtypeWarning: Columns (40,101,105) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk2:
# C:\Users\ying_\AppData\Local\Temp\ipykernel_13972\1563985282.py:6: DtypeWarning: Columns (40,101,105) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk2:
# C:\Users\ying_\AppData\Local\Temp\ipykernel_13972\1563985282.py:6: DtypeWarning: Columns (40,101,105) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk2:
# C:\Users\ying_\AppData\Local\Temp\ipykernel_13972\1563985282.py:6: DtypeWarning: Columns (39,40,101,105) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
q4 = r'C:\Users\ying_\SHERRY\mortgage\2012\2012Q4.csv'
output_file = "subset_2012_Q4.csv"

chunk4 = pd.read_csv(q4, delimiter='|', header=None, na_values=[',,', '', ','], skipinitialspace=True, chunksize=1000000)
first_chunk = True
for chunk in chunk4:
    chunk.columns = field_names
    chunk = chunk[columns_to_keep]
    if first_chunk:
        chunk.to_csv(output_file, index=False)
        first_chunk = False
    else:
        chunk.to_csv(output_file, mode='a', header=False, index=False)
# Out:
# C:\Users\ying_\AppData\Local\Temp\ipykernel_13972\853299255.py:6: DtypeWarning: Columns (40,101,105) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk4:
# C:\Users\ying_\AppData\Local\Temp\ipykernel_13972\853299255.py:6: DtypeWarning: Columns (40,101,105) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk4:
# C:\Users\ying_\AppData\Local\Temp\ipykernel_13972\853299255.py:6: DtypeWarning: Columns (40,101,105) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk4:
# C:\Users\ying_\AppData\Local\Temp\ipykernel_13972\853299255.py:6: DtypeWarning: Columns (40,105) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk4:
# C:\Users\ying_\AppData\Local\Temp\ipykernel_13972\853299255.py:6: DtypeWarning: Columns (40,101,105) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
d1.tail()
# Out:
#         Loan Identifier  Monthly Reporting Period Channel  \
# 999995     118580905076                     42015       C
# 999996     118580905076                     52015       C
# 999997     118580905076                     62015       C
# 999998     118580905076                     72015       C
# 999999     118580905076                     82015       C
#
#         Original Interest Rate  Current Interest Rate  Original UPB  \
# 999995                     3.5                    3.5      109000.0
# 999996                     3.5                    3.5      109000.0
# 999997                     3.5                    3.5      109000.0
# 999998                     3.5                    3.5      109000.0
# 999999                     3.5                    3.5      109000.0
#
#         Current Actual UPB  Original Loan Term  Origination Date  Loan Age  \
# 999995            89896.50                 180            122011      39.0
# ...

# %%
d1["Borrower Credit Score Current"].unique()
# Out:
# array([nan])

# %%
chunk_2 = pd.read_csv(q2, delimiter='|', header=None, na_values=[',,', '', ','], skipinitialspace=True, chunksize=1000000)
chunk_2_list = []
for chunk in chunk_2:
    chunk_2_list.append(chunk)
d2 = pd.concat(chunk_2_list)

# %%
chunk_3 = pd.read_csv(q3, delimiter='|', header=None, na_values=[',,', '', ','], skipinitialspace=True, chunksize=1000000)
chunk_3_list = []
for chunk in chunk_3:
    chunk_3_list.append(chunk)
d3 = pd.concat(chunk_3_list)

# %%
chunk_4 = pd.read_csv(q4, delimiter='|', header=None, na_values=[',,', '', ','], skipinitialspace=True, chunksize=1000000)
chunk_4_list = []
for chunk in chunk_4:
    chunk_4_list.append(chunk)
d4 = pd.concat(chunk_4_list)

# %%
field_names = [
    "Reference Pool ID", "Loan Identifier", "Monthly Reporting Period", "Channel",
    "Seller Name", "Servicer Name", "Master Servicer", "Original Interest Rate",
    "Current Interest Rate", "Original UPB", "UPB at Issuance", "Current Actual UPB",
    "Original Loan Term", "Origination Date", "First Payment Date", "Loan Age",
    "Remaining Months to Legal Maturity", "Remaining Months To Maturity", "Maturity Date",
    "Original Loan to Value Ratio (LTV)", "Original Combined Loan to Value Ratio (CLTV)",
    "Number of Borrowers", "Debt-To-Income (DTI)", "Borrower Credit Score at Origination",
    "Co-Borrower Credit Score at Origination", "First Time Home Buyer Indicator", "Loan Purpose",
    "Property Type", "Number of Units", "Occupancy Status", "Property State", "Metropolitan Statistical Area (MSA)",
    "Zip Code Short", "Mortgage Insurance Percentage", "Amortization Type", "Prepayment Penalty Indicator",
    "Interest Only Loan Indicator", "Interest Only First Principal And Interest Payment Date",
    "Months to Amortization", "Current Loan Delinquency Status", "Loan Payment History", "Modification Flag",
    "Mortgage Insurance Cancellation Indicator", "Zero Balance Code", "Zero Balance Effective Date",
    "UPB at the Time of Removal", "Repurchase Date", "Scheduled Principal Current", "Total Principal Current",
    "Unscheduled Principal Current", "Last Paid Installment Date", "Foreclosure Date", "Disposition Date",
    "Foreclosure Costs", "Property Preservation and Repair Costs", "Asset Recovery Costs", "Miscellaneous Holding Expenses and Credits",
    "Associated Taxes for Holding Property", "Net Sales Proceeds", "Credit Enhancement Proceeds", "Repurchase Make Whole Proceeds",
    "Other Foreclosure Proceeds", "Modification-Related Non-Interest Bearing UPB", "Principal Forgiveness Amount",
    "Original List Start Date", "Original List Price", "Current List Start Date", "Current List Price", "Borrower Credit Score At Issuance",
    "Co-Borrower Credit Score At Issuance", "Borrower Credit Score Current", "Co-Borrower Credit Score Current",
    "Mortgage Insurance Type", "Servicing Activity Indicator", "Current Period Modification Loss Amount",
    "Cumulative Modification Loss Amount", "Current Period Credit Event Net Gain or Loss", "Cumulative Credit Event Net Gain or Loss",
    "Special Eligibility Program", "Foreclosure Principal Write-off Amount", "Relocation Mortgage Indicator",
    "Zero Balance Code Change Date", "Loan Holdback Indicator", "Loan Holdback Effective Date", "Delinquent Accrued Interest",
    "Property Valuation Method", "High Balance Loan Indicator", "ARM Initial Fixed-Rate Period ≤ 5 YR Indicator", "ARM Product Type",
    "Initial Fixed-Rate Period", "Interest Rate Adjustment Frequency", "Next Interest Rate Adjustment Date", "Next Payment Change Date",
    "Index", "ARM Cap Structure", "Initial Interest Rate Cap Up Percent", "Periodic Interest Rate Cap Up Percent",
    "Lifetime Interest Rate Cap Up Percent", "Mortgage Margin", "ARM Balloon Indicator", "ARM Plan Number",
    "Borrower Assistance Plan", "High Loan to Value (HLTV) Refinance Option Indicator", "Deal Name", "Repurchase Make Whole Proceeds Flag",
    "Alternative Delinquency Resolution", "Alternative Delinquency  Resolution Count", "Total Deferral Amount",
    "Payment Deferral Modification Event Indicator", "Interest Bearing UPB"
]

# %%
d1.columns = field_names
d2.columns = field_names
d3.columns = field_names
d4.columns = field_names

# %%
original.head()

# %%
original['Current Loan Delinquency Status'].unique()
# original['Modification Flag'].head()

# %%
columns_to_keep = [
    "Loan Identifier",
    "Monthly Reporting Period",
    "Channel",
    "Original Interest Rate",
    "Current Interest Rate",
    "Original UPB",
    "Current Actual UPB",
    "Original Loan Term",
    "Origination Date",
    "Loan Age",
    "Original Loan to Value Ratio (LTV)",
    "Original Combined Loan to Value Ratio (CLTV)",
    "Number of Borrowers",
    "Debt-To-Income (DTI)",
    "Borrower Credit Score at Origination",
    "Co-Borrower Credit Score at Origination",
    "First Time Home Buyer Indicator",
    "Loan Purpose",
    "Property Type",
    "Number of Units",
    "Occupancy Status",
    "Property State",
    "Metropolitan Statistical Area (MSA)",
    "Zip Code Short",
    "Mortgage Insurance Percentage",
    "Amortization Type",
    "Prepayment Penalty Indicator",
    "Interest Only Loan Indicator",
    "Current Loan Delinquency Status",
    "Loan Payment History",
    "Modification Flag",
    "Mortgage Insurance Cancellation Indicator",
    "Zero Balance Code",
    "Zero Balance Effective Date",
    "UPB at the Time of Removal",
    "Borrower Credit Score Current",
    "Co-Borrower Credit Score Current",
    "Mortgage Insurance Type",
    "Property Valuation Method",
    "ARM Product Type"
]

# %%
df_filtered = original[columns_to_keep]
df_filtered.head()

# %%
df_filtered.to_csv('subset_2023Q4.csv', index=False)
